# %% [markdown]
# Importing the Dependencies

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# %% [markdown]
# Data Collection and Data Processing

# %%
#loading the dataset to a pandas Dataframe
sonar_data = pd.read_csv('sonardata.csv',header=None)

# %%
sonar_data.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  60
# 0  0.0090  0.0032   R
# 1  0.0052  0.0044   R
# 2  0.0095  0.0078   R
# 3  0.0040  0.0117   R
# 4  0.0107  0.0094   R
#
# [5 rows x 61 columns]

# %%
# Number of rows and columns
sonar_data.shape
# Out:
# (208, 61)

# %%
sonar_data.describe()
# descrive --> Statistical measure of the data
# Out:
#                0           1           3           4           5           6   \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     1.279593    0.038962    0.053942    0.075279    0.104281    0.121329
# std     18.026567    0.033488    0.046483    0.055485    0.059435    0.062190
# min      0.001500    0.000600    0.005800    0.006700    0.007000    0.003300
# 25%      0.013475    0.016450    0.024375    0.038050    0.066725    0.079325
# 50%      0.023000    0.030850    0.044050    0.062500    0.092150    0.106950
# 75%      0.036525    0.048575    0.064500    0.100275    0.134125    0.154000
# max    260.012300    0.233900    0.426400    0.401000    0.382300    0.372900
#
#                7           8           9           10  ...          50  \
# count  208.000000  208.000000  208.000000  208.000000  ...  208.000000
# mean     0.134787    0.178048    0.208474    0.236090  ...    0.016069
# std      0.085162    0.118358    0.134157    0.132618  ...    0.012008
# min      0.005500    0.007500    0.011300    0.028900  ...    0.000000
# 25%      0.080425    0.097375    0.111275    0.129250  ...    0.008425
# 50%      0.112100    0.152250    0.182400    0.224800  ...    0.013900
# 75%      0.169600    0.233425    0.268700    0.301650  ...    0.020825
# max      0.459000    0.682800    0.710600    0.734200  ...    0.100400
#
#                51          52          53          54          55          56  \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.013420    0.010709    0.010941    0.009290    0.008222    0.007820
# std      0.009634    0.007060    0.007301    0.007088    0.005736    0.005785
# min      0.000800    0.000500    0.001000    0.000600    0.000400    0.000300
# 25%      0.007275    0.005075    0.005375    0.004150    0.004400    0.003700
# 50%      0.011400    0.009550    0.009300    0.007500    0.006850    0.005950
# 75%      0.016725    0.014900    0.014500    0.012100    0.010575    0.010425
# max      0.070900    0.039000    0.035200    0.044700    0.039400    0.035500
#
#                57          58          59
# count  208.000000  208.000000  208.000000
# mean     0.007949    0.007941    0.006507
# std      0.006470    0.006181    0.005031
# min      0.000300    0.000100    0.000600
# 25%      0.003600    0.003675    0.003100
# 50%      0.005800    0.006400    0.005300
# 75%      0.010350    0.010325    0.008525
# max      0.044000    0.036400    0.043900
#
# [8 rows x 59 columns]

# %%
sonar_data[60].value_counts()
# Out:
# 60
# M    111
# R     97
# Name: count, dtype: int64

# %% [markdown]
# M --> Mine,
# R --> Rock

# %%
sonar_data.isnull().sum()
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 56    0
# 57    0
# 58    0
# 59    0
# 60    0
# Length: 61, dtype: int64

# %%
# Separating data and Labels
X = sonar_data.drop(columns=60,axis=1)
Y = sonar_data[60]
print(X)
print(Y)
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
#          9   ...      50      51      52      53      54      55      56  \
# 0    0.2111  ...  0.0232  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180
# 1    0.2872  ...  0.0125  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140
# 2    0.6194  ...  0.0033  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316
# 3    0.1264  ...  0.0241  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050
# 4    0.4459  ...  0.0156  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072
# ..      ...  ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.2684  ...  0.0203  0.0116  0.0098  0.0199  0.0033  0.0101  0.0065
# 204  0.2154  ...  0.0051  0.0061  0.0093  0.0135  0.0063  0.0063  0.0034
# 205  0.2529  ...  0.0155  0.0160  0.0029  0.0051  0.0062  0.0089  0.0140
# 206  0.2354  ...  0.0042  0.0086  0.0046  0.0126  0.0036  0.0035  0.0034
# 207  0.2354  ...  0.0181  0.0146  0.0129  0.0047  0.0039  0.0061  0.0040
#
#          57      58      59
# 0    0.0084  0.0090  0.0032
# 1    0.0049  0.0052  0.0044
# 2    0.0164  0.0095  0.0078
# 3    0.0044  0.0040  0.0117
# 4    0.0048  0.0107  0.0094
# ..      ...     ...     ...
# 203  0.0115  0.0193  0.0157
# 204  0.0032  0.0062  0.0067
# 205  0.0138  0.0077  0.0031
# 206  0.0079  0.0036  0.0048
# 207  0.0036  0.0061  0.0115
#
# [208 rows x 60 columns]
# 0      R
# 1      R
# 2      R
# 3      R
# 4      R
#       ..
# 203    M
# 204    M
# 205    M
# 206    M
# 207    M
# Name: 60, Length: 208, dtype: object

# %%
# Convert to numeric and handle errors
X = X.apply(pd.to_numeric, errors='coerce')

# %%
# Check for NaN values and handle them
X.fillna(X.mean(), inplace=True)

# %%
# Scaling the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# # Traning and Testing Data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scaled,Y,test_size=0.2,stratify=Y,random_state=23)

# %%
print(X_train.shape,Y_train.shape,X_test.shape)
# Out:
# (166, 60) (166,) (42, 60)

# %% [markdown]
# Model Training --> Logistic Regression

# %%
model = LogisticRegression()

# %%
# Training the Logistic regression model with training data
model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Model Evaluation

# %%
# Accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction,Y_train)

# %%
print('Accuracy on Training Data: ',training_data_accuracy)
# Out:
# Accuracy on Training Data:  0.9337349397590361

# %%
# Accuracy on Test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction,Y_test)

# %%
print('Accuracy on Test Data: ',test_data_accuracy)
# Out:
# Accuracy on Test Data:  0.7857142857142857

# %%
#Hyperparameter Tuning
from sklearn.model_selection import GridSearchCV

# Define the parameter grid
param_grid = {
    'C': [0.01, 0.1, 1, 10, 100],
    'penalty': ['l1', 'l2'],
    'solver': ['liblinear', 'saga']
}

# %%
# Grid Search
grid = GridSearchCV(LogisticRegression(), param_grid, cv=5)
grid.fit(X_train, Y_train)

print("Best parameters found: ", grid.best_params_)
print("Best cross-validation accuracy: ", grid.best_score_)
# Out:
# /Users/jeevanapathipati/Documents/MachineLearning/DataAnalysis/mlEnv/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/jeevanapathipati/Documents/MachineLearning/DataAnalysis/mlEnv/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/jeevanapathipati/Documents/MachineLearning/DataAnalysis/mlEnv/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/jeevanapathipati/Documents/MachineLearning/DataAnalysis/mlEnv/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/jeevanapathipati/Documents/MachineLearning/DataAnalysis/mlEnv/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/jeevanapathipati/Documents/MachineLearning/DataAnalysis/mlEnv/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/jeevanapathipati/Documents/MachineLearning/DataAnalysis/mlEnv/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/jeevanapathipati/Documents/MachineLearning/DataAnalysis/mlEnv/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/jeevanapathipati/Documents/MachineLearning/DataAnalysis/mlEnv/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/jeevanapathipati/Documents/MachineLearning/DataAnalysis/mlEnv/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/jeevanapathipati/Documents/MachineLearning/DataAnalysis/mlEnv/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/jeevanapathipati/Documents/MachineLearning/DataAnalysis/mlEnv/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/jeevanapathipati/Documents/MachineLearning/DataAnalysis/mlEnv/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/jeevanapathipati/Documents/MachineLearning/DataAnalysis/mlEnv/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/jeevanapathipati/Documents/MachineLearning/DataAnalysis/mlEnv/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/jeevanapathipati/Documents/MachineLearning/DataAnalysis/mlEnv/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/jeevanapathipati/Documents/MachineLearning/DataAnalysis/mlEnv/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/jeevanapathipati/Documents/MachineLearning/DataAnalysis/mlEnv/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/jeevanapathipati/Documents/MachineLearning/DataAnalysis/mlEnv/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Best parameters found:  {'C': 0.01, 'penalty': 'l2', 'solver': 'saga'}
# Best cross-validation accuracy:  0.7889483065953655
# /Users/jeevanapathipati/Documents/MachineLearning/DataAnalysis/mlEnv/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/jeevanapathipati/Documents/MachineLearning/DataAnalysis/mlEnv/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/jeevanapathipati/Documents/MachineLearning/DataAnalysis/mlEnv/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/jeevanapathipati/Documents/MachineLearning/DataAnalysis/mlEnv/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/jeevanapathipati/Documents/MachineLearning/DataAnalysis/mlEnv/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/jeevanapathipati/Documents/MachineLearning/DataAnalysis/mlEnv/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/jeevanapathipati/Documents/MachineLearning/DataAnalysis/mlEnv/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/jeevanapathipati/Documents/MachineLearning/DataAnalysis/mlEnv/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/jeevanapathipati/Documents/MachineLearning/DataAnalysis/mlEnv/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/jeevanapathipati/Documents/MachineLearning/DataAnalysis/mlEnv/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/jeevanapathipati/Documents/MachineLearning/DataAnalysis/mlEnv/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/jeevanapathipati/Documents/MachineLearning/DataAnalysis/mlEnv/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/jeevanapathipati/Documents/MachineLearning/DataAnalysis/mlEnv/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/jeevanapathipati/Documents/MachineLearning/DataAnalysis/mlEnv/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/jeevanapathipati/Documents/MachineLearning/DataAnalysis/mlEnv/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %%
# Evaluate the best model
best_model = grid.best_estimator_
X_test_prediction = best_model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
cv_scores = cross_val_score(best_model, X_scaled, Y, cv=5)
print("Cross-validation scores: ", cv_scores)
print("Mean cross-validation score: ", cv_scores.mean())
# Out:
# Cross-validation scores:  [0.5        0.80952381 0.71428571 0.82926829 0.46341463]
# Mean cross-validation score:  0.6632984901277583

# %% [markdown]
# Making  a Predictive System

# %%
input_data = (0.0394,0.0420,0.0446,0.0551,0.0597,0.1416,0.0956,0.0802,0.1618,0.2558,0.3078,0.3404,0.3400,0.3951,0.3352,0.2252,0.2086,0.2248,0.3382,0.4578,0.6474,0.6708,0.7007,0.7619,0.7745,0.6767,0.7373,0.7834,0.9619,1.0000,0.8086,0.5558,0.5409,0.4988,0.3108,0.2897,0.2244,0.0960,0.2287,0.3228,0.3454,0.3882,0.3240,0.0926,0.1173,0.0566,0.0766,0.0969,0.0588,0.0050,0.0118,0.0146,0.0040,0.0114,0.0032,0.0062,0.0101,0.0068,0.0053,0.0087)


input_data_as_array = np.asarray(input_data).reshape(1, -1)
input_data_scaled = scaler.transform(input_data_as_array)
prediction = model.predict(input_data_scaled)

if prediction[0] == 'R':
    print('The object is a Rock')
else:
    print('The object is a Mine')
# Out:
# The object is a Mine
